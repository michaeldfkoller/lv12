# %% [markdown]
# **Kommutation Functions**

# %% [markdown]
# \begin{eqnarray}
# A_x & = & \sum_{k=0} ^ \infty v^{k+1} {}_kp_x \, q_{x+k} \\
#     & = & \frac{M_x}{D_x}
# \end{eqnarray}

# %% [markdown]
# **Given a Mortality table (q_x)**
#
# Steps:
# - define decrement table
# - calculate commutation fuctions
# - apply them to an given insurance

# %% [markdown]
# **Decrement Table**
#
# - Define $l_0 = 100000$
# - Apply recursion $l_{x+1} = l_x \times (1-q_x)$
# - Calculate $d_x = l_{x+1} - lx$
#
# **Relationship between $l_x, d_x$ and things like ${}_kp_x$?**
#
# - $p_x = \frac{l_{x+1}}{l_x}$
# - $q_x = \frac{d_{x}}{l_x}$
# - ${}_kp_x = \frac{l_{x+k}}{l_x}$

# %% [markdown]
# **Commutation Function**
# \begin{eqnarray}
# D_x &=& l_x \times v^{x} \\
# C_x &=& d_x \times v^{x+1} \\
# N_x &=& \sum_{k=0}^\infty D_{x+k} \\
# M_x &=& \sum_{k=0}^\infty C_{x+k} \\
# S_x &=& \sum_{k=0}^\infty N_{x+k} \\
# R_x &=& \sum_{k=0}^\infty M_{x+k} \\
# \end{eqnarray}

# %% [markdown]
# **Application**
#
# \begin{eqnarray}
# A_x & = & \sum_{k=0} ^ \infty v^{k+1} {}_kp_x \, q_{x+k} \\
#     & = & \sum_{k=0} ^ \infty v^{k+1} \frac{l_{x+k}}{l_x} \, \frac{d_{x+k}}{l_{x+k}} \\
#      & = & \sum_{k=0} ^ \infty \frac{v^{x+k+1}}{v^x} \frac{l_{x+k}}{l_x} \, \frac{d_{x+k}}{l_{x+k}} \\
#      & = & \sum_{k=0} ^ \infty \frac{v^{x+k+1} \times d_{x+k}}{v^x \times l_x}\\
#      & = & \sum_{k=0} ^ \infty \frac{C_{x+k}}{D_x}\\
#     & = & \frac{M_x}{D_x}
# \end{eqnarray}

# %% [markdown]
# import math
# import numpy as np
#
# filename = "EK95.txt"
# EKMF95 = np.loadtxt(filename, skiprows=0)
#
# #print(EKMF95[20,:])
#
# def QxEK95(gender,x,t,param =[]):
#     return(EKMF95[x,gender+1])

# %%
print(QxEK95(1,20,0))
# Out:
# 0.0008533

# %% [markdown]
# **Decrement**
#
# $l_0 = 100000$
#
# $l_{x+1} = l_x * (1-q_x)$
#
# $d_x = l_x \times q_x $

# %%
import numpy as np

lx = np.zeros(120)
dx = np.zeros(120)

lx[0] =100000

for i in range(110):
    lx[i+1] = lx[i] * (1 - QxEK95(0,i,0))
    dx[i] = -lx[i+1] + lx[i]
    
    print("%3d:  %8.1f  %7.1f"%(i, lx[i], dx[i]))
# Out:
#   0:  100000.0    309.6
#   1:   99690.4    117.3
#   2:   99573.0     80.2
#   3:   99492.9     71.6
#   4:   99421.3     63.9
#   5:   99357.4     57.3
#   6:   99300.0     51.8
#   7:   99248.2     47.4
#   8:   99200.8     44.3
#   9:   99156.5     42.4
#  10:   99114.2     41.8
#  11:   99072.3     42.7
#  12:   99029.6     44.9
#  13:   98984.8     49.1
#  14:   98935.6     58.5
#  15:   98877.2     76.3
#  16:   98800.9    105.4
#  17:   98695.5    145.6
#  18:   98549.9    186.0
#  19:   98363.9    214.1
#  20:   98149.8    221.2
#  21:   97928.6    212.9
#  22:   97715.6    198.2
#  23:   97517.4    181.7
#  24:   97335.7    166.8
#  25:   97168.9    154.8
#  26:   97014.1    145.2
#  27:   96868.9    137.7
#  28:   96731.3    132.0
#  29:   96599.2    128.2
#  30:   96471.0    125.9
#  31:   96345.1    125.0
#  32:   96220.1    125.3
#  33:   96094.8    126.6
#  34:   95968.2    128.8
#  35:   95839.4    131.6
#  36:   95707.7    135.0
#  37:   95572.7    140.4
#  38:   95432.3    146.9
#  39:   95285.4    154.6
#  40:   95130.7    164.0
#  41:   94966.8    175.0
#  42:   94791.7    188.0
#  43:   94603.7    203.2
#  44:   94400.5    220.9
#  45:   94179.6    241.2
#  46:   93938.3    264.3
#  47:   93674.1    290.2
#  48:   93383.9    319.1
#  49:   93064.8    351.1
#  50:   92713.7    386.3
#  51:   92327.5    424.5
#  52:   91903.0    466.0
#  53:   91437.0    510.8
#  54:   90926.2    559.6
#  55:   90366.6    612.4
#  56:   89754.2    668.8
#  57:   89085.5    728.4
#  58:   88357.0    791.6
#  59:   87565.5    859.4
#  60:   86706.0    932.3
#  61:   85773.8   1007.5
#  62:   84766.3   1084.0
#  63:   83682.3   1163.9
#  64:   82518.4   1242.9
#  65:   81275.5   1322.4
#  66:   79953.1   1403.3
#  67:   78549.8   1484.9
#  68:   77064.9   1566.9
#  69:   75497.9   1648.8
#  70:   73849.2   1729.8
#  71:   72119.4   1810.6
#  72:   70308.8   1896.2
#  73:   68412.5   1991.8
#  74:   66420.7   2101.5
#  75:   64319.2   2228.1
#  76:   62091.1   2373.1
#  77:   59718.0   2536.3
#  78:   57181.7   2715.7
#  79:   54466.1   2907.4
#  80:   51558.7   3105.4
#  81:   48453.3   3284.2
#  82:   45169.0   3417.9
#  83:   41751.1   3503.3
#  84:   38247.8   3537.8
#  85:   34710.0   3520.8
#  86:   31189.1   3453.4
#  87:   27735.7   3338.4
#  88:   24397.3   3180.3
#  89:   21217.0   2985.1
#  90:   18231.9   2760.0
#  91:   15471.8   2513.0
#  92:   12958.8   2252.5
#  93:   10706.3   1986.7
#  94:    8719.7   1723.4
#  95:    6996.2   1469.9
#  96:    5526.4   1231.7
#  97:    4294.6   1013.6
#  98:    3281.0    818.7
#  99:    2462.3    648.5
# 100:    1813.9    503.4
# 101:    1310.4    382.8
# 102:     927.7    284.8
# 103:     642.9    207.2
# 104:     435.8    147.2
# 105:     288.6    102.1
# 106:     186.5     69.0
# 107:     117.5     45.4
# 108:      72.1     29.1
# 109:      43.0     18.1

# %% [markdown]
# ** Commutation Function**
#
# $D_x, N_x, S_x \leadsto l_x$
#
# $C_x, M_x, R_x \leadsto d_x$

# %%
iRate = 0.04
v = 1./(1+iRate)

Dx = np.zeros(120)
Cx = np.zeros(120)
Nx = np.zeros(120)
Mx = np.zeros(120)
Sx = np.zeros(120)
Rx = np.zeros(120)

for i in range(110):
    Dx[i] = lx[i] * v**i
    Cx[i] = dx[i] * v**(i+1)

for i in range(110):
    Nx[i] = sum(Dx[i:])
    Mx[i] = sum(Cx[i:])
    
for i in range(110):
    Sx[i] = sum(Nx[i:])
    Rx[i] = sum(Mx[i:])    
    
    print("%3d:  %8.1f  %8.1f  %16.1f  %16.1f %16.1f  %16.1f"%(i, Dx[i], Cx[i], Nx[i], Mx[i], Sx[i],Rx[i]))
# Out:
#   0:  100000.0     297.7         2417453.6            7020.7       52829013.3          385531.9
#   1:   95856.1     108.5         2317453.6            6723.0       50411559.7          378511.2
#   2:   92060.9      71.3         2221597.5            6614.5       48094106.0          371788.2
#   3:   88448.8      61.2         2129536.6            6543.2       45872508.5          365173.8
#   4:   84985.7      52.6         2041087.8            6482.0       43742971.9          358630.6
#   5:   81664.5      45.3         1956102.1            6429.5       41701884.1          352148.5
#   6:   78478.3      39.4         1874437.6            6384.2       39745782.0          345719.0
#   7:   75420.5      34.7         1795959.3            6344.8       37871344.4          339334.9
#   8:   72485.1      31.1         1720538.8            6310.2       36075385.1          332990.1
#   9:   69666.1      28.6         1648053.8            6279.1       34354846.3          326679.9
#  10:   66958.0      27.2         1578387.7            6250.4       32706792.5          320400.8
#  11:   64355.5      26.7         1511429.7            6223.2       31128404.8          314150.4
#  12:   61853.6      27.0         1447074.2            6196.6       29616975.1          307927.2
#  13:   59447.7      28.4         1385220.6            6169.6       28169900.9          301730.6
#  14:   57132.9      32.5         1325772.9            6141.3       26784680.3          295561.0
#  15:   54903.0      40.7         1268640.1            6108.8       25458907.4          289419.7
#  16:   52750.6      54.1         1213737.1            6068.1       24190267.3          283310.9
#  17:   50667.6      71.9         1160986.5            6014.0       22976530.2          277242.8
#  18:   48647.0      88.3         1110318.9            5942.1       21815543.7          271228.9
#  19:   46687.7      97.7         1061671.8            5853.8       20705224.9          265286.7
#  20:   44794.3      97.1         1014984.1            5756.1       19643553.1          259432.9
#  21:   42974.3      89.8          970189.9            5659.0       18628568.9          253676.8
#  22:   41231.6      80.4          927215.5            5569.2       17658379.0          248017.8
#  23:   39565.4      70.9          885983.9            5488.8       16731163.5          242448.7
#  24:   37972.8      62.6          846418.5            5417.9       15845179.6          236959.9
#  25:   36449.7      55.8          808445.7            5355.3       14998761.1          231542.0

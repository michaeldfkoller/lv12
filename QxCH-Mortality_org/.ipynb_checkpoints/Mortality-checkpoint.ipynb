# %%
import numpy as np
import matplotlib.pyplot as plt

strQx = "CH_qx.txt"
strQy = "CH_qy.txt"
strNx = "CH_bestand.txt"

def ReadDate(strqx,strqy,strbest):
    qxdict = dict() # qx(gender, time, age) returns (qx, nx, dx) # gender 0 man 1 woman
    QxRawData = np.loadtxt(strqx, skiprows=1)
    QyRawData = np.loadtxt(strqy, skiprows=1)
    BestRawData = np.loadtxt(strbest, skiprows=1)
    
    print("Processing Bestand")
    for i in range(len(BestRawData)):
        qxdict[(0,BestRawData[i,0],BestRawData[i,1])] = [None, BestRawData[i,2], None]
        qxdict[(1,BestRawData[i,0],BestRawData[i,1])] = [None, BestRawData[i,3], None]
    
    print("Processing Qx")
    for i in range(len(QxRawData)):
        t = QxRawData[i,0]
        x = QxRawData[i,1]
        qx = QxRawData[i,3]
        Nx = qxdict[(0,t,x)][1] 
        Dx = qx * Nx
        qxdict[(0,t,x)] = [qx, Nx, Dx]
 
    print("Processing Qy")
    for i in range(len(QyRawData)):
        t = QyRawData[i,0]
        x = QyRawData[i,1]
        qx = QyRawData[i,3]
        Nx = qxdict[(1,t,x)][1] 
        Dx = qx * Nx
        qxdict[(1,t,x)] = [qx, Nx, Dx]
    
    return qxdict

QxData = ReadDate(strQx,strQy,strNx)
# Out:
# Processing Bestand
# Processing Qx
# Processing Qy

# %%
print("test data man")

print(QxData[0,1876,0])
print(QxData[0,1876,10])
print(QxData[0,1877,0])
print(QxData[0,2018,0])
print(QxData[0,2018,10])
print(QxData[0,2002,79])

print("test data woman")

print(QxData[1,1876,0])
print(QxData[1,1876,10])
print(QxData[1,1877,0])
print(QxData[1,2018,0])
print(QxData[1,2018,10])
print(QxData[1,2002,79])

print("test plot")
t = 2018
x=[]
qx=[]
qy=[]
for i in range(0,110):
    x.append(i)
    qx.append(QxData[0,t,i][0])
    qy.append(QxData[1,t,i][0])
plt.figure(1)   
plt.semilogy(x,qx,x,qy)

x= 65
t=[]
qx=[]
qy=[]

for i in range(1876,2019):
    t.append(i)
    qx.append(QxData[0,i,x][0])
    qy.append(QxData[1,i,x][0])

plt.figure(2)   
plt.plot(t,qx,t,qy)
# Out:
# test data man
# [0.23462, 35215.22, 8262.1949164]
# [0.00404, 28064.83, 113.38191320000001]
# [0.22744, 34827.82, 7921.2393808]
# [0.00348, 41909.77, 145.8459996]
# [9e-05, 40989.23, 3.6890307000000004]
# [0.05816, 25599.5, 1488.8669200000002]
# test data woman
# [0.19617, 35823.19, 7027.435182300001]
# [0.00448, 27446.0, 122.95808]
# [0.19122, 35398.9, 6768.977658000001]
# [0.00316, 44116.19, 139.4071604]
# [0.00012, 43362.1, 5.2034519999999995]
# [0.03496, 16275.49, 568.9911304]
# test plot
# [<matplotlib.lines.Line2D at 0x118586c88>,
#  <matplotlib.lines.Line2D at 0x118586dd8>]

# %%
import math
import scipy
import scipy.optimize

def qxModel(age, myp):
    a=myp[0]
    b=myp[1]
    c=myp[2]
    return(math.exp(a+(b+c*age)*age))

t = 2018
x=[]
qx=[]
qy=[]
for i in range(0,110):
    x.append(i)
    qx.append(QxData[0,t,i][0])
    qy.append(QxData[1,t,i][0])
    
def MyErr(a):
    Err = 0
    for i in range(80):
        Err += (qxModel(i,a)-qx[i])**2
    return Err

qxp = [-9.13275,8.09432e-2,  -1.1018e-5]
d = scipy.optimize.fmin(MyErr, qxp, args=(), xtol=0.0001, ftol=0.0001, full_output = True)

print(d)

x=[]
qx1=[]
qx2=[]
for i in range(100):
    x.append(i)
    qx1.append(QxData[0,t,i][0])
    qx2.append(qxModel(i, d[0]))
    
plt.figure(3)
plt.semilogy(x,qx1,x,qx2)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000031
#          Iterations: 174
#          Function evaluations: 317
# (array([-9.33624292e+00,  4.65978557e-02,  3.83793181e-04]), 3.0649683734570654e-05, 174, 317, 0)
# [<matplotlib.lines.Line2D at 0x11b147a90>,
#  <matplotlib.lines.Line2D at 0x11d1994e0>]

# %%
def MyErr(a):
    Err = 0
    for i in range(15,100):
        Err += (qxModelMakeham(i,a)-qx[i])**2
    return Err

def qxModelMakeham(age, myp):
    x = age
    a=myp[0]
    b=myp[1]
    c=myp[2]
    d=myp[3] # if <> 0 Perks
    e=myp[4] # if <> 0 Perks
    return((a+b*math.exp(c*x))/(1+d*math.exp(c*x)+e*math.exp(-c*x)))



def qxModel2(age, myp):
    x = age
    a=myp[0]
    b=myp[1]
    c=myp[2]
    d=myp[3]
    e=myp[4]
    return((a+b*math.exp(c*x))/(1+d*math.exp(c*x)+e*math.exp(-c*x)))

def qxModel3(age, myp):
    a=myp[0]
    b=myp[1]
    return(math.exp(a+(b)*age))



T =range(1876,2018,10)
I =range(0,80)
P =range(0,101)

for t in T:
    #t = 2018
    x=[]
    qx=[]
    qy=[]
    for i in range(0,110):
        x.append(i)
        qx.append(QxData[0,t,i][0])
        qy.append(QxData[1,t,i][0])
    
    qxp = [0.0016,0.045,0.007,0.11,0.004]
    d = scipy.optimize.fmin(MyErr, qxp, args=(), xtol=0.001, ftol=0.001, full_output = True)

    print(d)
    
    x=[]
    qx1=[]
    qx2=[]
    for i in P:
        x.append(i)
        qx1.append(QxData[0,t,i][0])
        qx2.append(qxModelMakeham(i, d[0]))
   
    plt.figure(4)
    plt.semilogy(x,qx2)
    plt.grid(True)
    
    plt.figure(5)
    plt.semilogy(x,qx1)
    plt.grid(True)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.074927
#          Iterations: 81
#          Function evaluations: 138
# (array([ 0.00597463,  0.00851016,  0.03046771, -0.03421151, -0.01836884]), 0.07492733036232205, 81, 138, 0)
# Optimization terminated successfully.
#          Current function value: 0.093299
#          Iterations: 74
#          Function evaluations: 130
# (array([ 0.00184288,  0.01382574,  0.01939253, -0.12111257,  0.00605885]), 0.09329926830859919, 74, 130, 0)
# Optimization terminated successfully.
#          Current function value: 0.081446
#          Iterations: 85
#          Function evaluations: 146
# (array([ 0.00228264,  0.01253238,  0.01931005, -0.12268113,  0.00367656]), 0.08144604201528675, 85, 146, 0)
# Optimization terminated successfully.
#          Current function value: 0.101901
#          Iterations: 81
#          Function evaluations: 138
# (array([ 0.00195129,  0.01264599,  0.02108937, -0.10019055,  0.00190255]), 0.10190050446678436, 81, 138, 0)
# Optimization terminated successfully.
#          Current function value: 0.100775
#          Iterations: 78
#          Function evaluations: 136
# (array([ 0.00301994,  0.01210377,  0.020097  , -0.11439528,  0.00078521]), 0.10077472011246173, 78, 136, 0)
# Optimization terminated successfully.
#          Current function value: 0.072593
#          Iterations: 94
#          Function evaluations: 156
# (array([ 0.00408575,  0.00885901,  0.02541006, -0.06089031, -0.00721797]), 0.0725930390200998, 94, 156, 0)
# Optimization terminated successfully.
#          Current function value: 0.087532
#          Iterations: 76
#          Function evaluations: 129
# (array([ 0.00340724,  0.00891097,  0.02495299, -0.06795939, -0.00340169]), 0.08753206606361937, 76, 129, 0)
# Optimization terminated successfully.
#          Current function value: 0.073827
#          Iterations: 82
#          Function evaluations: 141
# (array([ 0.0047647 ,  0.00647057,  0.02924003, -0.04219304, -0.00420559]), 0.07382675968305097, 82, 141, 0)
# Optimization terminated successfully.
#          Current function value: 0.080825
#          Iterations: 81
#          Function evaluations: 138
# (array([ 0.00459996,  0.00583683,  0.03064304, -0.0365664 , -0.00398375]), 0.08082475704039244, 81, 138, 0)
# Optimization terminated successfully.
#          Current function value: 0.040283
#          Iterations: 79
#          Function evaluations: 140
# (array([ 0.00010011,  0.00367346,  0.03851857, -0.01490843, -0.0041253 ]), 0.040282682656656174, 79, 140, 0)
# Optimization terminated successfully.
#          Current function value: 0.069997
#          Iterations: 72
#          Function evaluations: 125
# (array([ 0.00104832,  0.00770339,  0.02253964, -0.09150069,  0.00800214]), 0.06999653930241062, 72, 125, 0)
# Optimization terminated successfully.
#          Current function value: 0.018439
#          Iterations: 93
#          Function evaluations: 161
# (array([ 0.00026872,  0.00090497,  0.05701355, -0.00130776, -0.01546704]), 0.018438812405696337, 93, 161, 0)
# Optimization terminated successfully.
#          Current function value: 0.032454
#          Iterations: 82
#          Function evaluations: 138
# (array([-0.00038833,  0.00305011,  0.03589917, -0.02173033,  0.000682  ]), 0.032454371580883205, 82, 138, 0)
# Optimization terminated successfully.
#          Current function value: 0.043823
#          Iterations: 63
#          Function evaluations: 113
# (array([ 0.0011939 ,  0.00443076,  0.02633341, -0.06310604,  0.00607083]), 0.043823056938299194, 63, 113, 0)
# Optimization terminated successfully.
#          Current function value: 0.033805
#          Iterations: 68
#          Function evaluations: 121
# (array([-9.22618216e-05,  3.04218330e-03,  3.13099498e-02, -3.80008220e-02,
#         6.54153679e-03]), 0.033805044398270756, 68, 121, 0)

# %%
def MyErr(a):
    Err = 0
    for i in range(10,80):
        Err += (qxModel3(i,a)-qx[i])**2
    return Err

def qxModelMakeham(age, myp):
    x = age
    a=myp[0]
    b=myp[1]
    c=myp[2]
    d=myp[3] # if <> 0 Perks
    e=myp[4] # if <> 0 Perks
    return((a+b*math.exp(c*x))/(1+d*math.exp(c*x)+e*math.exp(-c*x)))



def qxModel2(age, myp):
    x = age
    a=myp[0]
    b=myp[1]
    c=myp[2]
    d=myp[3]
    e=myp[4]
    return((a+b*math.exp(c*x))/(1+d*math.exp(c*x)+e*math.exp(-c*x)))

def qxModel3(age, myp):
    a=myp[0]
    b=myp[1]
    return(math.exp(a+(b)*age))



T =range(1876,2018,10)
I =range(0,80)
P =range(0,101)

for t in T:
    #t = 2018
    x=[]
    qx=[]
    qy=[]
    for i in range(0,110):
        x.append(i)
        qx.append(QxData[0,t,i][0])
        qy.append(QxData[1,t,i][0])
    
    qxp = [-9.13275,8.09432e-2,  -1.1018e-5]
    d = scipy.optimize.fmin(MyErr, qxp, args=(), xtol=0.001, ftol=0.001, full_output = True)

    print(d)
    
    x=[]
    qx1=[]
    qx2=[]
    for i in P:
        x.append(i)
        qx1.append(QxData[0,t,i][0])
        qx2.append(qxModel3(i, d[0]))
   
    plt.figure(6)
    plt.semilogy(x,qx2)
    plt.grid(True)
    
    plt.figure(7)
    plt.semilogy(x,qx1)
    plt.grid(True)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.001394
#          Iterations: 50
#          Function evaluations: 97
# (array([-7.15401859e+00,  6.76403287e-02, -1.77671289e-05]), 0.0013944308598201696, 50, 97, 0)
# Optimization terminated successfully.
#          Current function value: 0.001733
#          Iterations: 59
#          Function evaluations: 108
# (array([-7.86848263e+00,  7.68131844e-02, -1.17867216e-05]), 0.0017326567220342448, 59, 108, 0)
# Optimization terminated successfully.
#          Current function value: 0.001553
#          Iterations: 66
#          Function evaluations: 120
# (array([-7.62206966e+00,  7.21070409e-02, -1.27231871e-05]), 0.0015531601765734677, 66, 120, 0)
# Optimization terminated successfully.
#          Current function value: 0.000557
#          Iterations: 60
#          Function evaluations: 112
# (array([-7.73866802e+00,  7.36734176e-02, -1.07389595e-05]), 0.0005573391854030441, 60, 112, 0)
# Optimization terminated successfully.
#          Current function value: 0.000644
#          Iterations: 51
#          Function evaluations: 87
# (array([-8.23660052e+00,  7.99082136e-02, -1.19353558e-05]), 0.0006439628348361694, 51, 87, 0)
# Optimization terminated successfully.
#          Current function value: 0.000560
#          Iterations: 54
#          Function evaluations: 102
# (array([-8.66149147e+00,  8.42225130e-02, -1.13061210e-05]), 0.0005599234272473053, 54, 102, 0)
# Optimization terminated successfully.
#          Current function value: 0.000193
#          Iterations: 46
#          Function evaluations: 88
# (array([-8.81978618e+00,  8.58615424e-02, -1.07917953e-05]), 0.00019301501553898814, 46, 88, 0)
# Optimization terminated successfully.
#          Current function value: 0.000131
#          Iterations: 59
#          Function evaluations: 111
# (array([-9.39682618e+00,  9.24736924e-02, -8.08111571e-06]), 0.00013137496625599874, 59, 111, 0)
# Optimization terminated successfully.
#          Current function value: 0.000081
#          Iterations: 61
#          Function evaluations: 116
# (array([-9.76263017e+00,  9.63998165e-02, -7.93699481e-06]), 8.097785119446111e-05, 61, 116, 0)
# Optimization terminated successfully.
#          Current function value: 0.000114
#          Iterations: 53
#          Function evaluations: 95
# (array([-9.42907612e+00,  9.06261830e-02, -9.63769754e-06]), 0.00011398114521630002, 53, 95, 0)
# Optimization terminated successfully.
#          Current function value: 0.000064
#          Iterations: 48
#          Function evaluations: 89
# (array([-9.73108313e+00,  9.31073052e-02, -9.87486092e-06]), 6.420939582794903e-05, 48, 89, 0)
# Optimization terminated successfully.
#          Current function value: 0.000051
#          Iterations: 48
#          Function evaluations: 86
# (array([-9.89466582e+00,  9.30481193e-02, -8.82928416e-06]), 5.0917664712293875e-05, 48, 86, 0)
# Optimization terminated successfully.
#          Current function value: 0.000043
#          Iterations: 54
#          Function evaluations: 101
# (array([-1.05675661e+01,  9.95752180e-02, -9.51031816e-06]), 4.274841210582945e-05, 54, 101, 0)
# Optimization terminated successfully.
#          Current function value: 0.000035
#          Iterations: 62
#          Function evaluations: 115
# (array([-1.12332101e+01,  1.04612039e-01, -1.14498761e-05]), 3.5281370430578704e-05, 62, 115, 0)
# Optimization terminated successfully.
#          Current function value: 0.000012
#          Iterations: 52
#          Function evaluations: 100
# (array([-1.09024948e+01,  9.64338368e-02, -8.02424217e-06]), 1.1792780678130133e-05, 52, 100, 0)
